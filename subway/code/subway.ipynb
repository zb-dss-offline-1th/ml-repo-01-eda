# %%
import pandas as pd

# %%
data1 = pd.read_csv('./지하철/CARD_SUBWAY_MONTH_202201.csv', encoding='utf8', index_col=False)
data1
# Out:
#            사용일자    노선명     역명  승차총승객수  하차총승객수      등록일자
# 0      20220101    3호선     수서    7370    7076  20220104
# 1      20220101    3호선    학여울     461     473  20220104
# 2      20220101    3호선     대청    3224    2903  20220104
# 3      20220101    3호선     일원    3321    2803  20220104
# 4      20220101    경원선     창동       1       0  20220104
# ...         ...    ...    ...     ...     ...       ...
# 18516  20220131  우이신설선   솔밭공원     975     966  20220203
# 18517  20220131  우이신설선  북한산우이    1641    1683  20220203
# 18518  20220131    안산선    수리산    1333    1225  20220203
# 18519  20220131    안산선    오이도    3753    3975  20220203
# 18520  20220131    안산선     정왕    3878    3739  20220203
#
# [18521 rows x 6 columns]

# %%
data1[data1['역명']=='삼각지']
# Out:
#            사용일자  노선명   역명  승차총승객수  하차총승객수      등록일자
# 461    20220101  6호선  삼각지    2519    1941  20220104
# 546    20220101  4호선  삼각지    1657    2037  20220104
# 1013   20220102  6호선  삼각지    2536    2135  20220105
# 1097   20220102  4호선  삼각지    1974    2515  20220105
# 1379   20220103  4호선  삼각지    4305    4535  20220106
# ...         ...  ...  ...     ...     ...       ...
# 17093  20220129  4호선  삼각지    2730    3193  20220201
# 17666  20220130  6호선  삼각지    2705    2029  20220202
# 17751  20220130  4호선  삼각지    1860    2313  20220202
# 18274  20220131  6호선  삼각지    1920    1394  20220203
# 18358  20220131  4호선  삼각지    1281    1582  20220203
#
# [62 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.figure(figsize=(12,8))
plt.scatter(data=data1[data1['역명']=='삼각지'], x='사용일자', y='하차총승객수')

# %%
data2 = pd.read_csv('./지하철/서울교통공사_역별 일별 시간대별 승하차인원 정보_20220531.csv', encoding='cp949')
data2
# Out:
#           연번          날짜  호선   역번호   역명  구분  06시 이전  06시-07시  07시-08시  \
# 0          1  2022-01-01   1   150  서울역  승차     120      137      211
# 1          2  2022-01-01   1   150  서울역  하차     113      560      617
# 2          3  2022-01-01   1   151   시청  승차      38       66      101
# 3          4  2022-01-01   1   151   시청  하차      31      195      224
# 4          5  2022-01-01   1   152   종각  승차      44       71       86
# ...      ...         ...  ..   ...  ...  ..     ...      ...      ...
# 82341  82342  2022-05-31   8  2826   수진  하차      27       82      154
# 82342  82343  2022-05-31   8  2827   모란  승차      83      131      376
# 82343  82344  2022-05-31   8  2827   모란  하차      23      122      218
# 82344  82345  2022-05-31   8  2828  남위례  승차      47      203      759
# 82345  82346  2022-05-31   8  2828  남위례  하차      23      100      234
#
#        08시-09시  ...  14시-15시  15시-16시  16시-17시  17시-18시  18시-19시  19시-20시  \
# ...

# %%
data2.drop('연번', axis=1, inplace=True)

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82346 entries, 0 to 82345
# Data columns (total 24 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   날짜       82346 non-null  object
#  1   호선       82346 non-null  int64
#  2   역번호      82346 non-null  int64
#  3   역명       82346 non-null  object
#  4   구분       82346 non-null  object
#  5   06시 이전   82346 non-null  int64
#  6   06시-07시  82346 non-null  int64
#  7   07시-08시  82346 non-null  int64
#  8   08시-09시  82346 non-null  int64
#  9   09시-10시  82346 non-null  int64
#  10  10시-11시  82346 non-null  int64
#  11  11시-12시  82346 non-null  int64
#  12  12시-13시  82346 non-null  int64
#  13  13시-14시  82346 non-null  int64
#  14  14시-15시  82346 non-null  int64
#  15  15시-16시  82346 non-null  int64
#  16  16시-17시  82346 non-null  int64
#  17  17시-18시  82346 non-null  int64
#  18  18시-19시  82346 non-null  int64
#  19  19시-20시  82346 non-null  int64
#  20  20시-21시  82346 non-null  int64
# ...

# %%
data2.columns
# Out:
# Index(['날짜', '호선', '역번호', '역명', '구분', '06시 이전', '06시-07시', '07시-08시',
#        '08시-09시', '09시-10시', '10시-11시', '11시-12시', '12시-13시', '13시-14시',
#        '14시-15시', '15시-16시', '16시-17시', '17시-18시', '18시-19시', '19시-20시',
#        '20시-21시', '21시-22시', '22시-23시', '23시 이후'],
#       dtype='object')

# %%
data2.drop(['12시-13시', '13시-14시',
       '14시-15시', '15시-16시', '16시-17시', '17시-18시', '18시-19시', '19시-20시',
       '20시-21시', '21시-22시', '22시-23시', '23시 이후'], axis=1, inplace=True)

# %%
data2.head()
# Out:
#            날짜  호선  역번호   역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  09시-10시  \
# 0  2022-01-01   1  150  서울역  승차     120      137      211      439      592
# 1  2022-01-01   1  150  서울역  하차     113      560      617      910     1232
# 2  2022-01-01   1  151   시청  승차      38       66      101      139      121
# 3  2022-01-01   1  151   시청  하차      31      195      224      380      283
# 4  2022-01-01   1  152   종각  승차      44       71       86      158      158
#
#    10시-11시  11시-12시
# 0      878     1278
# 1     1260     1028
# 2      137      246
# 3      309      359
# 4      201      354

# %%
data2.drop('역번호', axis=1, inplace=True)

# %%
data2['날짜'] = pd.to_datetime(data2['날짜'], format='%Y-%m-%d')
data2.head()
# Out:
#           날짜  호선   역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  09시-10시  \
# 0 2022-01-01   1  서울역  승차     120      137      211      439      592
# 1 2022-01-01   1  서울역  하차     113      560      617      910     1232
# 2 2022-01-01   1   시청  승차      38       66      101      139      121
# 3 2022-01-01   1   시청  하차      31      195      224      380      283
# 4 2022-01-01   1   종각  승차      44       71       86      158      158
#
#    10시-11시  11시-12시
# 0      878     1278
# 1     1260     1028
# 2      137      246
# 3      309      359
# 4      201      354

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82346 entries, 0 to 82345
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   날짜       82346 non-null  datetime64[ns]
#  1   호선       82346 non-null  int64
#  2   역명       82346 non-null  object
#  3   구분       82346 non-null  object
#  4   06시 이전   82346 non-null  int64
#  5   06시-07시  82346 non-null  int64
#  6   07시-08시  82346 non-null  int64
#  7   08시-09시  82346 non-null  int64
#  8   09시-10시  82346 non-null  int64
#  9   10시-11시  82346 non-null  int64
#  10  11시-12시  82346 non-null  int64
# dtypes: datetime64[ns](1), int64(8), object(2)
# memory usage: 6.9+ MB

# %%
data2['Weekday'] = 0

# %%
for idx, row in data2.iterrows():
    if row['날짜'].weekday() > 4:
        data2.loc[idx, 'Weekday'] = 1

# %%
data2
# Out:
#               날짜  호선   역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  09시-10시  \
# 0     2022-01-01   1  서울역  승차     120      137      211      439      592
# 1     2022-01-01   1  서울역  하차     113      560      617      910     1232
# 2     2022-01-01   1   시청  승차      38       66      101      139      121
# 3     2022-01-01   1   시청  하차      31      195      224      380      283
# 4     2022-01-01   1   종각  승차      44       71       86      158      158
# ...          ...  ..  ...  ..     ...      ...      ...      ...      ...
# 82341 2022-05-31   8   수진  하차      27       82      154      452      211
# 82342 2022-05-31   8   모란  승차      83      131      376      525      274
# 82343 2022-05-31   8   모란  하차      23      122      218      469      186
# 82344 2022-05-31   8  남위례  승차      47      203      759      857      438
# 82345 2022-05-31   8  남위례  하차      23      100      234      864      352
#
#        10시-11시  11시-12시  Weekday
# 0          878     1278        1
# ...

# %%
df = data2.loc[(data2['역명']== '삼각지') | (data2['역명']== '이태원') | (data2['역명']== '신용산')]

# %%
df.head()
# Out:
#             날짜  호선   역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  09시-10시  \
# 224 2022-01-01   4  삼각지  승차      16       21       38       51       65
# 225 2022-01-01   4  삼각지  하차      11       26       42       67       91
# 226 2022-01-01   4  신용산  승차      21       37       59      123      116
# 227 2022-01-01   4  신용산  하차      20      118      182      247      389
# 384 2022-01-01   6  삼각지  승차      17       51       43       63       73
#
#      10시-11시  11시-12시  Weekday
# 224       61      106        1
# 225       90      120        1
# 226      169      256        1
# 227      400      434        1
# 384       74      174        1

# %%
df = df[df['구분'] == '하차']
df
# Out:
#               날짜  호선   역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  09시-10시  \
# 225   2022-01-01   4  삼각지  하차      11       26       42       67       91
# 227   2022-01-01   4  신용산  하차      20      118      182      247      389
# 385   2022-01-01   6  삼각지  하차       4       27       41       63       89
# 389   2022-01-01   6  이태원  하차      28       92       72      134      187
# 769   2022-01-02   4  삼각지  하차       7       32       43       84       90
# ...          ...  ..  ...  ..     ...      ...      ...      ...      ...
# 81643 2022-05-30   6  이태원  하차      33      239      479     1229      966
# 82025 2022-05-31   4  삼각지  하차      17      325      568      864      467
# 82027 2022-05-31   4  신용산  하차      38      475     1454     4261     2922
# 82187 2022-05-31   6  삼각지  하차      36      327      718     1327      545
# 82191 2022-05-31   6  이태원  하차      38      230      423     1356     1063
#
#        10시-11시  11시-12시  Weekday
# 225         90      120        1
# ...

# %%
df = df[df['Weekday'] == 0]

# %%
df
# Out:
#               날짜  호선   역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  09시-10시  \
# 1313  2022-01-03   4  삼각지  하차      17      132      344      777      403
# 1315  2022-01-03   4  신용산  하차      48      419     1428     4175     2508
# 1473  2022-01-03   6  삼각지  하차      28      168      548     1038      323
# 1477  2022-01-03   6  이태원  하차      31      211      443      982      748
# 1859  2022-01-04   4  삼각지  하차      16      136      390      816      386
# ...          ...  ..  ...  ..     ...      ...      ...      ...      ...
# 81643 2022-05-30   6  이태원  하차      33      239      479     1229      966
# 82025 2022-05-31   4  삼각지  하차      17      325      568      864      467
# 82027 2022-05-31   4  신용산  하차      38      475     1454     4261     2922
# 82187 2022-05-31   6  삼각지  하차      36      327      718     1327      545
# 82191 2022-05-31   6  이태원  하차      38      230      423     1356     1063
#
#        10시-11시  11시-12시  Weekday
# 1313       222      203        0
# ...

# %%
df['Post'] = 0
# Out:
# /var/folders/_m/9sycz7bj0vlcb0sqw1yc6q400000gn/T/ipykernel_1899/2516210921.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Post'] = 0

# %%
df.head()
# Out:
#              날짜  호선   역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  09시-10시  \
# 1313 2022-01-03   4  삼각지  하차      17      132      344      777      403
# 1315 2022-01-03   4  신용산  하차      48      419     1428     4175     2508
# 1473 2022-01-03   6  삼각지  하차      28      168      548     1038      323
# 1477 2022-01-03   6  이태원  하차      31      211      443      982      748
# 1859 2022-01-04   4  삼각지  하차      16      136      390      816      386
#
#       10시-11시  11시-12시  Weekday  Post
# 1313      222      203        0     0
# 1315      905      596        0     0
# 1473      172      142        0     0
# 1477      398      364        0     0
# 1859      265      203        0     0

# %%
threshold = '2022-05-10'
thresh = pd.to_datetime(threshold, format='%Y-%m-%d')
for idx, row in df.iterrows():
    if row['날짜'] > thresh:
        df.loc[idx, 'Post'] = 1

# %%
df.head()
# Out:
#              날짜  호선   역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  09시-10시  \
# 1313 2022-01-03   4  삼각지  하차      17      132      344      777      403
# 1315 2022-01-03   4  신용산  하차      48      419     1428     4175     2508
# 1473 2022-01-03   6  삼각지  하차      28      168      548     1038      323
# 1477 2022-01-03   6  이태원  하차      31      211      443      982      748
# 1859 2022-01-04   4  삼각지  하차      16      136      390      816      386
#
#       10시-11시  11시-12시  Weekday  Post
# 1313      222      203        0     0
# 1315      905      596        0     0
# 1473      172      142        0     0
# 1477      398      364        0     0
# 1859      265      203        0     0

# %%
df
# Out:
#               날짜  호선   역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  09시-10시  \
# 1313  2022-01-03   4  삼각지  하차      17      132      344      777      403
# 1315  2022-01-03   4  신용산  하차      48      419     1428     4175     2508
# 1473  2022-01-03   6  삼각지  하차      28      168      548     1038      323
# 1477  2022-01-03   6  이태원  하차      31      211      443      982      748
# 1859  2022-01-04   4  삼각지  하차      16      136      390      816      386
# ...          ...  ..  ...  ..     ...      ...      ...      ...      ...
# 81643 2022-05-30   6  이태원  하차      33      239      479     1229      966
# 82025 2022-05-31   4  삼각지  하차      17      325      568      864      467
# 82027 2022-05-31   4  신용산  하차      38      475     1454     4261     2922
# 82187 2022-05-31   6  삼각지  하차      36      327      718     1327      545
# 82191 2022-05-31   6  이태원  하차      38      230      423     1356     1063
#
#        10시-11시  11시-12시  Weekday  Post
# 1313       222      203        0     0
# ...

# %%
df[df['날짜'] == '2022-05-11']
# Out:
#               날짜  호선   역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  09시-10시  \
# 71113 2022-05-11   4  삼각지  하차      15      191      525      839      434
# 71115 2022-05-11   4  신용산  하차      38      468     1461     4180     2941
# 71273 2022-05-11   6  삼각지  하차      37      276      811     1289      474
# 71277 2022-05-11   6  이태원  하차      34      231      482     1389      982
#
#        10시-11시  11시-12시  Weekday  Post
# 71113      292      283        0     1
# 71115     1150      775        0     1
# 71273      255      232        0     1
# 71277      624      510        0     1

# %%
from matplotlib import rc  ### 이 줄과
rc('font', family='AppleGothic') 			## 이 두 줄을 
plt.rcParams['axes.unicode_minus'] = False  ## 추가해줍니다. 

plt.figure(figsize=(12,8))
sns.barplot(data=df, x='역명', y='09시-10시', hue='Post')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.barplot(data=df, x='역명', y='08시-09시', hue='Post')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.barplot(data=df, x='역명', y='10시-11시', hue='Post')
plt.show()

# %%
df.columns
# Out:
# Index(['날짜', '호선', '역명', '구분', '06시 이전', '06시-07시', '07시-08시', '08시-09시',
#        '09시-10시', '10시-11시', '11시-12시', 'Weekday', 'Post'],
#       dtype='object')

# %%
df
# Out:
#               날짜  호선   역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  09시-10시  \
# 1313  2022-01-03   4  삼각지  하차      17      132      344      777      403
# 1315  2022-01-03   4  신용산  하차      48      419     1428     4175     2508
# 1473  2022-01-03   6  삼각지  하차      28      168      548     1038      323
# 1477  2022-01-03   6  이태원  하차      31      211      443      982      748
# 1859  2022-01-04   4  삼각지  하차      16      136      390      816      386
# ...          ...  ..  ...  ..     ...      ...      ...      ...      ...
# 81643 2022-05-30   6  이태원  하차      33      239      479     1229      966
# 82025 2022-05-31   4  삼각지  하차      17      325      568      864      467
# 82027 2022-05-31   4  신용산  하차      38      475     1454     4261     2922
# 82187 2022-05-31   6  삼각지  하차      36      327      718     1327      545
# 82191 2022-05-31   6  이태원  하차      38      230      423     1356     1063
#
#        10시-11시  11시-12시  Weekday  Post
# 1313       222      203        0     0
# ...

# %%
df['Passengers'] = df['08시-09시'] + df['09시-10시'] + df['10시-11시']
# Out:
# /var/folders/_m/9sycz7bj0vlcb0sqw1yc6q400000gn/T/ipykernel_1899/3433024308.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Passengers'] = df['08시-09시'] + df['09시-10시'] + df['10시-11시']

# %%
df['Weekday'].value_counts()
# Out:
# 0    428
# Name: Weekday, dtype: int64

# %%
df_group = df.groupby(['날짜', '역명'])['Passengers'].sum().reset_index()

# %%
df_group
# Out:
#             날짜   역명  Passengers
# 0   2022-01-03  삼각지        2935
# 1   2022-01-03  신용산        7588
# 2   2022-01-03  이태원        2128
# 3   2022-01-04  삼각지        3147
# 4   2022-01-04  신용산        7600
# ..         ...  ...         ...
# 316 2022-05-30  신용산        8559
# 317 2022-05-30  이태원        2688
# 318 2022-05-31  삼각지        3847
# 319 2022-05-31  신용산        8249
# 320 2022-05-31  이태원        2969
#
# [321 rows x 3 columns]

# %%
df_group['Post'] = int(0)

# %%
for idx, row in df_group.iterrows():
    if row['날짜'] > thresh:
        df_group.loc[idx, 'Post'] = int(1)

# %%
df_group
# Out:
#             날짜   역명  Passengers  Post
# 0   2022-01-03  삼각지        2935     0
# 1   2022-01-03  신용산        7588     0
# 2   2022-01-03  이태원        2128     0
# 3   2022-01-04  삼각지        3147     0
# 4   2022-01-04  신용산        7600     0
# ..         ...  ...         ...   ...
# 316 2022-05-30  신용산        8559     1
# 317 2022-05-30  이태원        2688     1
# 318 2022-05-31  삼각지        3847     1
# 319 2022-05-31  신용산        8249     1
# 320 2022-05-31  이태원        2969     1
#
# [321 rows x 4 columns]

# %%
plt.figure(figsize=(12,8))
sns.lineplot(data=df_group, x='날짜', y='Passengers', hue='역명')
plt.axvline(x=thresh, color='r', linestyle='--')
plt.show()

# %%
df_group.sort_values('Passengers', ascending=True).head(10)
# Out:
#             날짜   역명  Passengers  Post
# 63  2022-02-01  삼각지         330     0
# 60  2022-01-31  삼각지         365     0
# 65  2022-02-01  이태원         378     0
# 68  2022-02-02  이태원         473     0
# 66  2022-02-02  삼각지         486     0
# 64  2022-02-01  신용산         587     0
# 62  2022-01-31  이태원         624     0
# 123 2022-03-01  삼각지         634     0
# 141 2022-03-09  삼각지         712     0
# 125 2022-03-01  이태원         811     0

# %%
idx = df_group.index[(df_group['날짜']=='2022-01-31') | (df_group['날짜']=='2022-02-01') | (df_group['날짜']=='2022-02-02') | (df_group['날짜']=='2022-03-01') | (df_group['날짜']=='2022-03-09') | (df_group['날짜']=='2022-05-05')].tolist()

# %%
df2 = df_group.drop(idx, axis=0).reset_index(drop=True)

# %%
df2.head()
# Out:
#           날짜   역명  Passengers  Post
# 0 2022-01-03  삼각지        2935     0
# 1 2022-01-03  신용산        7588     0
# 2 2022-01-03  이태원        2128     0
# 3 2022-01-04  삼각지        3147     0
# 4 2022-01-04  신용산        7600     0

# %%
plt.figure(figsize=(12,8))
sns.lineplot(data=df2, x='날짜', y='Passengers', hue='역명')
plt.axvline(x=thresh, color='r', linestyle='--', label='5/11 집무실 이전')
plt.axvline(x=pd.to_datetime('2022-04-18', format='%Y-%m-%d'), color='k', linestyle='--', label='4/18 거리두기 해제')
plt.legend()
plt.show()

# %%
df2[df2['역명']=='신용산'].tail(20)
# Out:
#             날짜   역명  Passengers  Post
# 244 2022-05-03  신용산        8259     0
# 247 2022-05-04  신용산        8335     0
# 250 2022-05-06  신용산        5486     0
# 253 2022-05-09  신용산        8456     0
# 256 2022-05-10  신용산        8622     0
# 259 2022-05-11  신용산        8271     1
# 262 2022-05-12  신용산        8337     1
# 265 2022-05-13  신용산        7477     1
# 268 2022-05-16  신용산        8404     1
# 271 2022-05-17  신용산        8543     1
# 274 2022-05-18  신용산        8295     1
# 277 2022-05-19  신용산        8319     1
# 280 2022-05-20  신용산        7489     1
# 283 2022-05-23  신용산        8317     1
# 286 2022-05-24  신용산        8336     1
# 289 2022-05-25  신용산        8223     1
# 292 2022-05-26  신용산        8173     1
# 295 2022-05-27  신용산        7420     1
# 298 2022-05-30  신용산        8559     1
# 301 2022-05-31  신용산        8249     1

# %%
df2.to_csv('./subway_raw.csv', encoding='utf-8-sig', index=False)

# %%
data_21 = pd.read_csv('./지하철/서울교통공사 2021년 일별 역별 시간대별 승하차인원(1_8호선).csv', encoding='cp949')

# %%
data_21
# Out:
#             연번          날짜  호선   역번호   역명  구분  06시 이전  06시-07시  07시-08시  \
# 0            1  2021-01-01   1   150  서울역  승차      86      111      157
# 1            2  2021-01-01   1   150  서울역  하차      85      355      438
# 2            3  2021-01-01   1   151   시청  승차      43       45       75
# 3            4  2021-01-01   1   151   시청  하차      40      145      176
# 4            5  2021-01-01   1   152   종각  승차      49       59       89
# ...        ...         ...  ..   ...  ...  ..     ...      ...      ...
# 204369  204370  2021-12-31   8  2826   수진  하차      25       75       96
# 204370  204371  2021-12-31   8  2827   모란  승차      44      102      279
# 204371  204372  2021-12-31   8  2827   모란  하차      20       96      120
# 204372  204373  2021-12-31   8  2828  남위례  승차      20       83      279
# 204373  204374  2021-12-31   8  2828  남위례  하차      10       41      119
#
#         08시-09시  ...  15시-16시  16시-17시  17시-18시  18시-19시  19시-20시  20시-21시  \
# ...

# %%
data_21.columns
# Out:
# Index(['연번', '날짜', '호선', '역번호', '역명', '구분', '06시 이전', '06시-07시', '07시-08시',
#        '08시-09시', '09시-10시', '10시-11시', '11시-12시', '12시-13시', '13시-14시',
#        '14시-15시', '15시-16시', '16시-17시', '17시-18시', '18시-19시', '19시-20시',
#        '20시-21시', '21시-22시', '22시-23시', '23시 이후', '합 계'],
#       dtype='object')

# %%
data_21.drop(['연번', '호선', '역번호', '06시 이전', '06시-07시', '07시-08시', '11시-12시', '12시-13시', '13시-14시',
       '14시-15시', '15시-16시', '16시-17시', '17시-18시', '18시-19시', '19시-20시',
       '20시-21시', '21시-22시', '22시-23시', '23시 이후', '합 계'], axis=1, inplace=True)

# %%
data_21.head()
# Out:
#            날짜   역명  구분  08시-09시  09시-10시  10시-11시
# 0  2021-01-01  서울역  승차      306      333      416
# 1  2021-01-01  서울역  하차      592      841      747
# 2  2021-01-01   시청  승차      111       95       76
# 3  2021-01-01   시청  하차      312      223      189
# 4  2021-01-01   종각  승차      126      125      113

# %%
data_21['날짜'] = pd.to_datetime(data_21['날짜'], format='%Y-%m-%d')

# %%
df_2 = data_21[(data_21['구분'] == '하차')]

# %%
df_2['Passengers'] = df_2['08시-09시'] + df_2['09시-10시'] + df_2['10시-11시']
# Out:
# /var/folders/_m/9sycz7bj0vlcb0sqw1yc6q400000gn/T/ipykernel_1899/4206284471.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['Passengers'] = df_2['08시-09시'] + df_2['09시-10시'] + df_2['10시-11시']

# %%
df_2 = df_2.groupby(['날짜', '역명'])['Passengers'].sum().reset_index()
df_2.head()
# Out:
#           날짜       역명  Passengers
# 0 2021-01-01     가락시장         648
# 1 2021-01-01  가산디지털단지         999
# 2 2021-01-01       강남        2449
# 3 2021-01-01     강남구청         677
# 4 2021-01-01       강동         506

# %%
df_2['Weekend'] = int(0)
df_2['Post'] = int(0)

for idx, row in df_2.iterrows():
    if row['날짜'].weekday() > 4:
        df_2.loc[idx, 'Weekend'] = 1
    if row['날짜'] > thresh:
        df_2.loc[idx, 'Post'] = int(1)

# %%
idx = df_2.index[(df_2['날짜']=='2022-01-31') | (df_2['날짜']=='2022-02-01') | (df_2['날짜']=='2022-02-02') | (df_2['날짜']=='2022-03-01') | (df_2['날짜']=='2022-03-09') | (df_2['날짜']=='2022-05-05')].tolist()
df_2.loc[idx, 'Weekend'] = int(1)

# %%
df_2_selected = df_2.loc[(df_2['Weekend'] == 0) & ((df_2['역명']=='삼각지') | (df_2['역명']=='신용산') | (df_2['역명']=='녹사평(용산구청)'))]

# %%
plt.figure(figsize=(12,8))
sns.lineplot(data=df_2_selected, x='날짜', y='Passengers', hue='역명')
# plt.axvline(x=thresh, color='r', linestyle='--', label='5/11 집무실 이전')
# plt.axvline(x=pd.to_datetime('2022-04-18', format='%Y-%m-%d'), color='k', linestyle='--', label='4/18 거리두기 해제')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.lineplot(data=df2, x='날짜', y='Passengers', hue='역명')
plt.axvline(x=thresh, color='r', linestyle='--', label='5/11 집무실 이전')
plt.axvline(x=pd.to_datetime('2022-04-18', format='%Y-%m-%d'), color='k', linestyle='--', label='4/18 거리두기 해제')
plt.legend()
plt.show()

# %%
data20 = pd.read_csv('./지하철/서울교통공사 2020년 일별 역별 시간대별 승하차인원(1_8호선).csv', encoding='cp949')

# %%
data20.columns
# Out:
# Index(['날짜', '호선', '역번호', '역명', '구분', '06:00 이전', '06:00 ~ 07:00',
#        '07:00 ~ 08:00', '08:00 ~ 09:00', '09:00 ~ 10:00', '10:00 ~ 11:00',
#        '11:00 ~ 12:00', '12:00 ~ 13:00', '13:00 ~ 14:00', '14:00 ~ 15:00',
#        '15:00 ~ 16:00', '16:00 ~ 17:00', '17:00 ~ 18:00', '18:00 ~ 19:00',
#        '19:00 ~ 20:00', '20:00 ~ 21:00', '21:00 ~ 22:00', '22:00 ~ 23:00',
#        '23:00 ~ 24:00', '24:00 이후'],
#       dtype='object')

# %%
data20.drop(['호선', '역번호', '06:00 이전', '06:00 ~ 07:00',
       '07:00 ~ 08:00', '11:00 ~ 12:00', '12:00 ~ 13:00', '13:00 ~ 14:00', '14:00 ~ 15:00',
       '15:00 ~ 16:00', '16:00 ~ 17:00', '17:00 ~ 18:00', '18:00 ~ 19:00',
       '19:00 ~ 20:00', '20:00 ~ 21:00', '21:00 ~ 22:00', '22:00 ~ 23:00',
       '23:00 ~ 24:00', '24:00 이후'], axis=1, inplace=True)

data20['날짜'] = pd.to_datetime(data20['날짜'], format='%Y-%m-%d')
df_3 = data20[(data20['구분'] == '하차')]
df_3['Passengers'] = df_3['08:00 ~ 09:00'] + df_3['09:00 ~ 10:00'] + df_3['10:00 ~ 11:00']
df_3 = df_3.groupby(['날짜', '역명'])['Passengers'].sum().reset_index()
df_3['Weekend'] = int(0)
df_3['Post'] = int(0)

for idx, row in df_3.iterrows():
    if row['날짜'].weekday() > 4:
        df_3.loc[idx, 'Weekend'] = 1
    if row['날짜'] > thresh:
        df_3.loc[idx, 'Post'] = int(1)

df_3_selected = df_3.loc[(df_3['Weekend'] == 0) & ((df_3['역명']=='삼각지') | (df_3['역명']=='신용산') | (df_3['역명']=='녹사평(용산구청)'))]
# Out:
# /var/folders/_m/9sycz7bj0vlcb0sqw1yc6q400000gn/T/ipykernel_1899/2670562262.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3['Passengers'] = df_3['08:00 ~ 09:00'] + df_3['09:00 ~ 10:00'] + df_3['10:00 ~ 11:00']

# %%
plt.figure(figsize=(12,8))
sns.lineplot(data=df_2_selected, x='날짜', y='Passengers', hue='역명')
# plt.axvline(x=thresh, color='r', linestyle='--', label='5/11 집무실 이전')
# plt.axvline(x=pd.to_datetime('2022-04-18', format='%Y-%m-%d'), color='k', linestyle='--', label='4/18 거리두기 해제')
plt.legend()
plt.show()

# %%
data22 = pd.read_csv('./지하철/서울교통공사_역별 일별 시간대별 승하차인원 정보_20220531.csv', encoding='cp949')

# %%
data22.columns
# Out:
# Index(['연번', '날짜', '호선', '역번호', '역명', '구분', '06시 이전', '06시-07시', '07시-08시',
#        '08시-09시', '09시-10시', '10시-11시', '11시-12시', '12시-13시', '13시-14시',
#        '14시-15시', '15시-16시', '16시-17시', '17시-18시', '18시-19시', '19시-20시',
#        '20시-21시', '21시-22시', '22시-23시', '23시 이후'],
#       dtype='object')

# %%
data22.drop(['연번', '호선', '역번호', '06시 이전', '06시-07시', '07시-08시', '11시-12시', '12시-13시', '13시-14시',
       '14시-15시', '15시-16시', '16시-17시', '17시-18시', '18시-19시', '19시-20시',
       '20시-21시', '21시-22시', '22시-23시', '23시 이후'], axis=1, inplace=True)


data22['날짜'] = pd.to_datetime(data22['날짜'], format='%Y-%m-%d')
df_1 = data22[(data22['구분'] == '하차')]
df_1['Passengers'] = df_1['08시-09시'] + df_1['09시-10시'] + df_1['10시-11시']
df_1 = df_1.groupby(['날짜', '역명'])['Passengers'].sum().reset_index()
df_1['Weekend'] = int(0)
df_1['Post'] = int(0)

for idx, row in df_1.iterrows():
    if row['날짜'].weekday() > 4:
        df_1.loc[idx, 'Weekend'] = 1
    if row['날짜'] > thresh:
        df_1.loc[idx, 'Post'] = int(1)

df_1_selected = df_1.loc[(df_1['Weekend'] == 0) & ((df_1['역명']=='삼각지') | (df_1['역명']=='신용산') | (df_1['역명']=='녹사평(용산구청)'))]
# Out:
# /var/folders/_m/9sycz7bj0vlcb0sqw1yc6q400000gn/T/ipykernel_1899/582597401.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Passengers'] = df_1['08시-09시'] + df_1['09시-10시'] + df_1['10시-11시']

# %%
df_concat = pd.concat([df_1_selected, df_2_selected, df_3_selected], axis=0, ignore_index=True)

# %%
df_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1890 entries, 0 to 1889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   날짜          1890 non-null   datetime64[ns]
#  1   역명          1890 non-null   object
#  2   Passengers  1890 non-null   int64
#  3   Weekend     1890 non-null   int64
#  4   Post        1890 non-null   int64
#  5   Year        0 non-null      float64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(1)
# memory usage: 88.7+ KB

# %%
import numpy as np

# %%
df_concat['Year'] = np.NaN
n= 0
for idx, row in df_concat.iterrows():
    val = row['날짜'].strftime("%Y")
    df_concat.loc[idx, 'Year'] = val

# %%
df_concat['Date'] = np.NaN
for idx, row in df_concat.iterrows():
    val = '1990-' + row['날짜'].strftime("%m-%d")
    df_concat.loc[idx, 'Date'] = val

# %%
df_concat.head()
# Out:
#           날짜         역명  Passengers  Weekend  Post  Year        Date
# 0 2022-01-03  녹사평(용산구청)        1358        0     0  2022  1990-01-03
# 1 2022-01-03        삼각지        2935        0     0  2022  1990-01-03
# 2 2022-01-03        신용산        7588        0     0  2022  1990-01-03
# 3 2022-01-04  녹사평(용산구청)        1315        0     0  2022  1990-01-04
# 4 2022-01-04        삼각지        3147        0     0  2022  1990-01-04

# %%
df_concat.to_csv('./subway_concat.csv', encoding='utf-8-sig', index=False)

# %%
data19 = pd.read_excel('./지하철/서울교통공사 2019년 일별 역별 시간대별 승하차인원(1_8호선).xlsx', skiprows=1)

# %%
data19.columns
# Out:
# Index(['날짜', '호선', '역번호', '역명', '구분', '06시 이전', '06 ~ 07', '07 ~ 08',
#        '08 ~ 09', '09 ~ 10', '10 ~ 11', '11 ~ 12', '12 ~ 13', '13 ~ 14',
#        '14 ~ 15', '15 ~ 16', '16 ~ 17', '17 ~ 18', '18 ~ 19', '19 ~ 20',
#        '20 ~ 21', '21 ~ 22', '22 ~ 23', '23 ~ 24', '24시 이후', '합 계'],
#       dtype='object')

# %%
data19.drop(['호선', '역번호', '06시 이전', '06 ~ 07', '07 ~ 08', '11 ~ 12', '12 ~ 13', '13 ~ 14',
       '14 ~ 15', '15 ~ 16', '16 ~ 17', '17 ~ 18', '18 ~ 19', '19 ~ 20',
       '20 ~ 21', '21 ~ 22', '22 ~ 23', '23 ~ 24', '24시 이후', '합 계'], axis=1, inplace=True)


data19['날짜'] = pd.to_datetime(data19['날짜'], format='%Y-%m-%d')
df_4 = data19[(data19['구분'] == '하차')]
df_4['Passengers'] = df_4['08 ~ 09'] + df_4['09 ~ 10'] + df_4['10 ~ 11']
df_4 = df_4.groupby(['날짜', '역명'])['Passengers'].sum().reset_index()
df_4['Weekend'] = int(0)
df_4['Post'] = int(0)

for idx, row in df_4.iterrows():
    if row['날짜'].weekday() > 4:
        df_4.loc[idx, 'Weekend'] = 1
    if row['날짜'] > thresh:
        df_4.loc[idx, 'Post'] = int(1)

df_4_selected = df_4.loc[(df_4['Weekend'] == 0) & ((df_4['역명']=='삼각지') | (df_4['역명']=='신용산') | (df_4['역명']=='녹사평(용산구청)'))]
# Out:
# /var/folders/_m/9sycz7bj0vlcb0sqw1yc6q400000gn/T/ipykernel_1899/2783970684.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_4['Passengers'] = df_4['08 ~ 09'] + df_4['09 ~ 10'] + df_4['10 ~ 11']

# %%
df_concat_2 = pd.concat([df_concat, df_4_selected], axis=0, ignore_index=True)

# %%
df_concat_2
# Out:
#              날짜         역명  Passengers  Weekend  Post  Year        Date
# 0    2022-01-03  녹사평(용산구청)        1358        0     0  2022  1990-01-03
# 1    2022-01-03        삼각지        2935        0     0  2022  1990-01-03
# 2    2022-01-03        신용산        7588        0     0  2022  1990-01-03
# 3    2022-01-04  녹사평(용산구청)        1315        0     0  2022  1990-01-04
# 4    2022-01-04        삼각지        3147        0     0  2022  1990-01-04
# ...         ...        ...         ...      ...   ...   ...         ...
# 2668 2019-12-30        삼각지        3337        0     0   NaN         NaN
# 2669 2019-12-30        신용산        7784        0     0   NaN         NaN
# 2670 2019-12-31  녹사평(용산구청)        1083        0     0   NaN         NaN
# 2671 2019-12-31        삼각지        3211        0     0   NaN         NaN
# 2672 2019-12-31        신용산        7013        0     0   NaN         NaN
#
# [2673 rows x 7 columns]

# %%
df_concat_2['Year'] = np.NaN
n= 0
for idx, row in df_concat_2.iterrows():
    val = row['날짜'].strftime("%Y")
    df_concat_2.loc[idx, 'Year'] = val

df_concat_2['Date'] = np.NaN
for idx, row in df_concat_2.iterrows():
    val = '1990-' + row['날짜'].strftime("%m-%d")
    df_concat_2.loc[idx, 'Date'] = val

# %%
df_concat_2.to_csv('./subway_concat_v2.0.csv', encoding='utf-8-sig', index=False)
